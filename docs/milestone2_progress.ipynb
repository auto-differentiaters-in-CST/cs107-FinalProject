# %% [markdown]
# ## Task Assignment for Milestone2
#
# 1. main functions:
#    - AD:
#       - addition, subtraction, mod                              - Xiaohan Yang
#       - multiplication, division, power                         - Max Li
#       - diff, jacobian                                           - Xiaohan Yang
#
#    - admath:
#       - helper function: chain_rule                             - Runting Yang
#       - elementary functions: abs, exp, log, pow, sqrt.         - Runting Yang
#       - trig, hyperbolic trig, inverse (all)                    - Hanwen Zhang
#
# 2. test suite
#    - AD:
#       - addition, subtraction, mod                               - Xiaohan Yang
#       - multiplication, division, power                          - Max Li
#       - diff, jacobian                                            - Xiaohan Yang
#    - admath:
#       - helper function: chain_rule                              - Runting Yang
#       - elementary functions: abs, exp, log, pow, sqrt.          - Runting Yang
#       - trig, hyperbolic trig, inverse (all)                     - Hanwen Zhang
#
#    - applications in numerical algorithms                        - Hanwen Zhang
#
# 3. organizae and distribute the package                          - Xiaohan Yang
# 4. update documents                                              - All together

# %% [markdown]
# ## Progress
#
# Since the submission of Milestone1, each member has done the followning things.
# - Xiaohan: updated the milestone1 document, set up the project with pyScaffold, finished assigned dunder methods and the diff method, finished corresponding test suite.
# - Max: updated the milestone1 document, finished assigned dunder methods and corresponding test suite.
# - Runting: updated the milestone1 document, finished function implements and some tests.
# - Hanwen: updated the milestone1 document, finished assigned admath functions
